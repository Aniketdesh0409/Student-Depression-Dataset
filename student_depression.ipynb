# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Student Depression Dataset.csv")

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
df.shape
# Out:
# (27901, 18)

# %%
df[df["City"]=="Bangalore"].shape
# Out:
# (767, 18)

# %%
df.query('City=="Jaipur"')
# Out:
#            id  Gender   Age    City Profession  Academic Pressure  \
# 4          32  Female  25.0  Jaipur    Student                4.0
# 32        239    Male  21.0  Jaipur    Student                1.0
# 60        348    Male  25.0  Jaipur    Student                5.0
# 108       592    Male  27.0  Jaipur    Student                2.0
# 127       681    Male  26.0  Jaipur    Student                3.0
# ...       ...     ...   ...     ...        ...                ...
# 27754  139879    Male  22.0  Jaipur    Student                2.0
# 27784  140024    Male  29.0  Jaipur    Student                1.0
# 27835  140312  Female  24.0  Jaipur    Student                3.0
# 27872  140518    Male  34.0  Jaipur    Student                4.0
# 27886  140601  Female  22.0  Jaipur    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 4                0.0  8.13                 3.0               0.0
# ...

# %%
df.query('City=="Bangalore" &  Age<30')
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 1           8  Female  24.0  Bangalore    Student                2.0
# 24        173    Male  18.0  Bangalore    Student                4.0
# 117       623  Female  23.0  Bangalore    Student                5.0
# 160       779    Male  20.0  Bangalore    Student                5.0
# 202       984    Male  22.0  Bangalore    Student                1.0
# ...       ...     ...   ...        ...        ...                ...
# 27196  137131    Male  27.0  Bangalore    Student                1.0
# 27253  137412  Female  28.0  Bangalore    Student                2.0
# 27286  137603    Male  20.0  Bangalore    Student                4.0
# 27290  137629  Female  20.0  Bangalore    Student                4.0
# 27318  137764    Male  22.0  Bangalore    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 1                0.0  5.90                 5.0               0.0
# ...

# %%
df.groupby("Degree")["Work/Study Hours","CGPA","Financial Stress"].mean()
# Out:
# <ipython-input-19-1fdf9b95983b>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("Degree")["Work/Study Hours","CGPA","Financial Stress"].mean()
#           Work/Study Hours      CGPA  Financial Stress
# Degree
# B.Arch            7.266576  7.616502          3.172530
# B.Com             7.227756  7.671826          3.115538
# B.Ed              7.164971  7.850911          3.078242
# B.Pharm           6.708642  7.707753          3.103704
# B.Tech            7.070312  7.636513          3.050347
# BA                7.195000  7.761300          2.988333
# BBA               7.031609  7.714468          3.206897
# BCA               7.226797  7.769281          3.114525
# BE                7.161501  7.484617          3.143556
# BHM               7.069189  7.649859          3.060541
# BSc               7.248874  7.576824          3.127252
# Class 12          7.278289  7.594184          3.279276
# ...

# %%
df.groupby("Degree")["Work/Study Hours","CGPA","Financial Stress"].mean().head(5)
# Out:
# <ipython-input-21-a6d266a07a62>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("Degree")["Work/Study Hours","CGPA","Financial Stress"].mean().head(5)
#          Work/Study Hours      CGPA  Financial Stress
# Degree
# B.Arch           7.266576  7.616502          3.172530
# B.Com            7.227756  7.671826          3.115538
# B.Ed             7.164971  7.850911          3.078242
# B.Pharm          6.708642  7.707753          3.103704
# B.Tech           7.070312  7.636513          3.050347

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
df["CGPA"].value_counts().head(10)
# Out:
# 8.04    821
# 9.96    425
# 5.74    410
# 8.95    371
# 9.21    343
# 7.25    339
# 7.09    320
# 7.88    318
# 9.44    317
# 8.91    276
# Name: CGPA, dtype: int64
